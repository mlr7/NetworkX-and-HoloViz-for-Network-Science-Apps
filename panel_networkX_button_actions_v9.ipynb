# %%
# %matplotlib inline

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import networkx as nx

import panel as pn
pn.extension()

import hvplot
import hvplot.networkx as hvnx

import random
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
def color_edge():
    
    nodes = 5
    
    g = nx.complete_graph(nodes)
    pos = nx.circular_layout(g)
    
    #g.add_edge(1,2, color='r', weight=7)
    
    nx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)
    
    node1 = random.randint(0,(nodes-1))
    node2 = random.randint(0,(nodes-1))
    
    nx.draw_networkx_edges(g, pos, edgelist=[(node1,node2)],
                       width=8, edge_color="tab:red")
    
    return g

# %%
color_edge()

# %%
button_highlight = pn.widgets.Button(name='Highlight Link')
button_highlight.on_click(color_edge)
# Out:
# Watcher(inst=Button(name='Highlight Link'), cls=<class 'panel.widgets.button.Button'>, fn=<function color_edge at 0x0000022BCDB1C1F0>, mode='args', onlychanged=False, parameter_names=('clicks',), what='value', queued=False, precedence=0)

# %%
interactive = pn.bind(color_edge, button_highlight)

# %%
#app1 = pn.Column('## App-1', button_highlight, color_edge, align="center")
#app1 = pn.Column('## App-1', color_edge, align="center")

#app1 = pn.Column('## App-1', interactive)

app1 = pn.Column('## App-1', button_highlight, align="center")

app1
# Out:
# Column(align='center')
#     [0] Markdown(str)
#     [1] Button(name='Highlight Link')

# %%
app2 = pn.Column('## App-2', color_edge, align="center")

app2
# Out:
# Column(align='center')
#     [0] Markdown(str)
#     [1] Column
#         [0] Column()
#         [1] Row
#             [0] Str(Graph, name='interactive01403')

# %% [markdown]
# ### Older Code Below

# %%
def complete_graph(pts=15):
    
    g = nx.complete_graph(pts)
    pos = nx.circular_layout(g)
    
    return hvnx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)

# %%
g = nx.complete_graph(15)
pos = nx.circular_layout(g)
#g.add_edge(1,2, color='r', weight=70)

#colors = nx.get_edge_attributes(g, 'color').values()
#colors
#nx.draw(g, edge_color=colors)

nx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)

nx.draw_networkx_edges(g, pos, edgelist=[(4,12)],
                       width=8, edge_color="tab:red")

# %%
g = nx.complete_graph(15)
pos = nx.circular_layout(g)
#g.add_edge(1,2, color='r', weight=70)

#colors = nx.get_edge_attributes(g, 'color').values()
#colors
#nx.draw(g, edge_color=colors)

nx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)

nx.draw_networkx_edges(g, pos, edgelist=[(4,12)],
                       width=8, edge_color="tab:red")

nx.draw_networkx_edges(g, pos, edgelist=[(9,0)],
                       width=8, edge_color="tab:red")

# %%
def complete_graph_coloredge(pts=15, edgelist1=[(1,2)]):
    
    g = nx.complete_graph(pts)
    pos = nx.circular_layout(g)
    
    #g.add_edge(1,2, color='r', weight=7)
    
    nx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)
    
    nx.draw_networkx_edges(g, pos, edgelist=edgelist1, # edgelist=[(1,2)]
                       width=8, edge_color="tab:red")
    
    #return hvnx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)
    return g

# %%
complete_graph_coloredge(5, [(2,4)]);

# %%
d1 = complete_graph(5)
d2 = color_edge(d1, 1,2)
d1

# %%
points = pn.widgets.IntSlider(name = 'nodes', value=15,  start=1, end=30)
interactive = pn.bind(complete_graph, pts=points)

# %%
graphity_app1 = pn.Column('## Graphity App-1', points, interactive, align="center")
graphity_app1

# %%
graphity_app1.show()
